# %%
import os
import pandas as pd
import numpy as np
data_parent_dir = "/hpf/projects/ccmuhn/peds-delirium"

df_patient = pd.read_excel(os.path.join(data_parent_dir, "patient 2024-05-30.xlsx"))
print("patient")
print(df_patient.head())
print(df_patient.columns)
print(df_patient.shape)
print()

print(len(np.unique(df_patient['mrn'])))

print()
print('-'*100)
print()

df_flowsheets = pd.read_excel(os.path.join(data_parent_dir, "flowsheets 2024-05-30.xlsx"))
print("flowsheets")
print(df_flowsheets.head())
print(df_flowsheets.columns)
print(df_flowsheets.shape)
print()
print(len(np.unique(df_flowsheets['mrn'])))
print(len(np.unique(df_flowsheets['REDIR_PAT_ENC_CSN_ID'])))

print()
print('-'*100)
print()

df_medications = pd.read_excel(os.path.join(data_parent_dir, "medication administration 2024-05-30.xlsx"))
print("medications")
print(df_medications.head())
print(df_medications.columns)
print(df_medications.shape)
print()
print(len(np.unique(df_medications['mrn'])))
print(len(np.unique(df_medications['pat_enc_csn_id'])))

print()
print('-'*100)
print()

df_diagnosis = pd.read_excel(os.path.join(data_parent_dir, "diagnosis 2024-05-30.xlsx"))

print("diagnosis")
print(df_diagnosis.head())
print(df_diagnosis.columns)
print(df_diagnosis.shape)
print()
print(len(np.unique(df_diagnosis['mrn'])))
print(len(np.unique(df_diagnosis['pat_enc_csn_id'])))

print()
print('-'*100)
print()

df_notes = pd.read_parquet(os.path.join(data_parent_dir, "note 2024-05-31.parquet"), engine="pyarrow")
print("notes")
print(df_notes.head())
print(df_notes.columns)
print(df_notes.shape)
print()
print(len(np.unique(df_notes['mrn'])))
print(len(np.unique(df_notes['pat_enc_csn_id'])))

print()
print('-'*100)
print()
# Out:
# patient
#        mrn     sex  year_of_birth  month_of_birth  day_of_birth date_of_birth
# 0  2041202  Female           2001              11            13    2001-11-13
# 1  2043981  Female           2001              10            18    2001-10-18
# 2  2044540  Female           2001              12            12    2001-12-12
# 3  2065052    Male           2002               6            13    2002-06-13
# 4  2067118    Male           2002               7             2    2002-07-02
# Index(['mrn', 'sex', 'year_of_birth', 'month_of_birth', 'day_of_birth',
#        'date_of_birth'],
#       dtype='object')
# (5879, 6)
#
# 5879
#
# ----------------------------------------------------------------------------------------------------
#
# flowsheets
#        mrn  REDIR_PAT_ENC_CSN_ID AdmissionDate DischargeDate  \
# 0  2211389              22356290    2020-12-12    2021-06-02
# 1  2211389              22356290    2020-12-12    2021-06-02
# 2  2211389              22356290    2020-12-12    2021-06-02
# 3  2211389              22356290    2020-12-12    2021-06-02
# 4  2211389              22356290    2020-12-12    2021-06-02
#
#         RECORDED_TIME  FLO_MEAS_ID                   FLO_MEAS_NAME  \
# 0 2021-04-14 05:00:00    304400025     SK IP R CAPD 5 RESTLESSNESS
# 1 2021-04-14 05:00:00    304400028   SK IP R CAPD 8 RESPONSIVENESS
# 2 2021-04-14 08:05:00    304400023        SK IP R CAPD 3 AWARENESS
# 3 2021-04-14 08:05:00    304400026  SK IP R CAPD 6 INCONSOLABILITY
# 4 2021-04-16 18:00:00    304400022          SK IP R CAPD 2 ACTIONS
#
#                                            DISP_NAME MEAS_VALUE MEAS_COMMENT
# 0                             Is the child restless?          0          NaN
# 1  Does it take the child a long time to respond ...          0          NaN
# 2        Is the child aware of his/her surroundings?          0          NaN
# 3                         Is the child inconsolable?          0          NaN
# 4                Are the child's actions purposeful?          0          NaN
# Index(['mrn', 'REDIR_PAT_ENC_CSN_ID', 'AdmissionDate', 'DischargeDate',
#        'RECORDED_TIME', 'FLO_MEAS_ID', 'FLO_MEAS_NAME', 'DISP_NAME',
#        'MEAS_VALUE', 'MEAS_COMMENT'],
#       dtype='object')
# (192807, 10)
#
# 2613
# 3014
#
# ----------------------------------------------------------------------------------------------------
#
# medications
#    order_id  admin_line_num      mrn     pat_id  pat_enc_csn_id  \
# 0   1170763               1  2614645  Z00796207        18631693
# 1   1170764               1  2614645  Z00796207        18631693
# 2  18541048               1  2756587   Z1244839        29725060
# 3  18541048              21  2756587   Z1244839        29725060
# 4  18541048              47  2756587   Z1244839        29725060
#
#    medication_id                                 order_display_name  \
# 0      408601351                           0.9% NaCl bolus 1,366 mL
# 1      408700062                            cefTRIaxone 2,000 mg IV
# 2      408601803  heparin 100 unit in 0.9% NaCl 50 mL (2 units/m...
# 3      408601803  heparin 100 unit in 0.9% NaCl 50 mL (2 units/m...
# 4      408601803  heparin 100 unit in 0.9% NaCl 50 mL (2 units/m...
#
#        order_datetime order_start_datetime  order_end_datetime  ...  \
# 0 2019-09-23 22:03:14  2019-09-23 22:04:00 2019-09-23 22:19:00  ...
# 1 2019-09-23 22:03:14  2019-09-23 22:04:00 2019-09-23 22:19:00  ...
# 2 2023-01-28 09:26:10  2023-01-28 09:45:00 2023-02-09 07:20:27  ...
# 3 2023-01-28 09:26:10  2023-01-28 09:45:00 2023-02-09 07:20:27  ...
# 4 2023-01-28 09:26:10  2023-01-28 09:45:00 2023-02-09 07:20:27  ...
#
#   dosage_order_amount dosage_order_unit dosage_given_amount dosage_given_unit  \
# 0                  20        mL/kg/dose              1000.0                mL
# 1                2000                mg              2000.0                mg
# 2                   2             mL/hr                 2.0             mL/hr
# 3                   2             mL/hr                 2.0             mL/hr
# 4                   2             mL/hr                 2.0             mL/hr
#
#   dosing_bsa dosing_height dosing_weight  dosing_frequency medication_route  \
# 0        NaN           NaN          68.3              Once      Intravenous
# 1        NaN           NaN          68.3              Once      Intravenous
# 2        NaN           NaN          18.0        Continuous   Intra-Arterial
# 3        NaN           NaN          18.0        Continuous   Intra-Arterial
# 4        NaN           NaN          18.0        Continuous   Intra-Arterial
#
#              etl_datetime
# 0 2023-05-19 05:17:12.410
# 1 2023-05-19 05:17:12.410
# 2 2023-05-19 05:17:12.410
# 3 2023-05-19 05:17:12.410
# 4 2023-05-19 05:17:12.410
#
# [5 rows x 25 columns]
# Index(['order_id', 'admin_line_num', 'mrn', 'pat_id', 'pat_enc_csn_id',
#        'medication_id', 'order_display_name', 'order_datetime',
#        'order_start_datetime', 'order_end_datetime', 'admin_datetime',
#        'admin_action', 'drug_code', 'medication_name', 'simple_generic_name',
#        'dosage_order_amount', 'dosage_order_unit', 'dosage_given_amount',
#        'dosage_given_unit', 'dosing_bsa', 'dosing_height', 'dosing_weight',
#        'dosing_frequency', 'medication_route', 'etl_datetime'],
#       dtype='object')
# (867796, 25)
#
# 1893
# 5370
#
# ----------------------------------------------------------------------------------------------------
#
# diagnosis
#    diagnosis_id      mrn    pat_id  pat_enc_csn_id       dx_id  \
# 0       1000046  2248082  Z2259476      14605771.0      146762
# 1       1000069  2554989  Z1712181      14611530.0  3000001338
# 2       1000353  2248082  Z2259476      14605771.0      119206
# 3       1000436  2652146  Z1768269      14611129.0      134690
# 4       1000437  2554989  Z1712181      14611530.0      134693
#
#                   diagnosis_name diagnosis_code   code_set diagnosis_source  \
# 0           Post-operative state          Z98.8  ICD-10-CM        admission
# 1                      Scoliosis         M41.99  ICD-10-CM        admission
# 2  OSA (obstructive sleep apnea)         G47.30  ICD-10-CM        admission
# 3  Juvenile idiopathic scoliosis         M41.19  ICD-10-CM        admission
# 4        Neuromuscular scoliosis         M41.49  ICD-10-CM        admission
#
#         date date_resolution         date_description resolved_date  \
# 0 2020-08-05             day  hospital admission date           NaT
# 1 2019-10-21             day  hospital admission date           NaT
# 2 2020-08-05             day  hospital admission date           NaT
# 3 2020-08-31             day  hospital admission date           NaT
# 4 2019-10-21             day  hospital admission date           NaT
#
#    is_chronic            etl_datetime
# 0         NaN 2023-05-19 05:13:44.323
# 1         NaN 2023-05-19 05:13:44.323
# 2         NaN 2023-05-19 05:13:44.323
# 3         NaN 2023-05-19 05:13:44.323
# 4         NaN 2023-05-19 05:13:44.323
# Index(['diagnosis_id', 'mrn', 'pat_id', 'pat_enc_csn_id', 'dx_id',
#        'diagnosis_name', 'diagnosis_code', 'code_set', 'diagnosis_source',
#        'date', 'date_resolution', 'date_description', 'resolved_date',
#        'is_chronic', 'etl_datetime'],
#       dtype='object')
# (47200, 15)
#
# 5860
# 14707
#
# ----------------------------------------------------------------------------------------------------
#
# notes
#      note_id      mrn    pat_id  pat_enc_csn_id note_type_id  \
# 0  131926394  5449055  Z3059345      24688608.0          *60
# 1  131926715  5413444  Z3006501      24723949.0      1000011
# 2  131926792  5068338  Z2546800      24313026.0            1
# 3  131926809  5442640  Z3050141      24515471.0          *60
# 4  131926913  2326274  Z2293117      24376238.0            1
#
#                  note_type note_status                 service  \
# 0  Radiology Study Results        None                    None
# 1            Nursing Notes      Signed                    None
# 2           Progress Notes      Signed           Physiotherapy
# 3  Radiology Study Results        None                    None
# 4           Progress Notes      Signed  Bone Marrow Transplant
#
#                  author     create_datetime     filing_datetime  \
# 0                  None                 NaT                 NaT
# 1         WARSAME, AMAL 2021-08-24 16:13:59 2021-08-24 18:57:04
# 2  PATTERSON, CATHERINE 2021-08-24 11:06:00 2021-08-24 16:28:38
# 3                  None                 NaT                 NaT
# 4          MARWA, BILAL 2021-08-24 16:25:49 2021-08-25 08:02:40
#
#                                            note_text            etl_datetime
# 0    PICC Insertion    Procedure performed by Dr.... 2023-05-19 12:54:55.007
# 1  Assessment:  Received patient asleep with mom ... 2023-05-19 12:54:55.007
# 2  S: Nurse reports that this am they gave hypert... 2023-05-19 12:54:55.007
# 3  HISTORY:  Postoperative TGA repair with right ... 2023-05-19 12:54:55.007
# 4      BMT/CT Inpatient Progress Note       Audre... 2023-05-19 12:54:55.007
# Index(['note_id', 'mrn', 'pat_id', 'pat_enc_csn_id', 'note_type_id',
#        'note_type', 'note_status', 'service', 'author', 'create_datetime',
#        'filing_datetime', 'note_text', 'etl_datetime'],
#       dtype='object')
# (820750, 13)
#
# 5879
# 23918
#
# ----------------------------------------------------------------------------------------------------

# %%
df_notes[df_notes['mrn']=='5449055']
# Out:
#           note_id      mrn    pat_id  pat_enc_csn_id note_type_id  \
# 0       131926394  5449055  Z3059345      24688608.0          *60
# 36      131928853  5449055  Z3059345      24688608.0       304073
# 87      132143454  5449055  Z3059345      24688608.0       304651
# 93      132144588  5449055  Z3059345      24688608.0           70
# 99      132147241  5449055  Z3059345      24688608.0      1000011
# ...           ...      ...       ...             ...          ...
# 820262  131949772  5449055  Z3059345      24688608.0            1
# 820380  131986347  5449055  Z3059345      24688608.0           70
# 820508  132053606  5449055  Z3059345      24688608.0       304651
# 820524  132055923  5449055  Z3059345      24688608.0            1
# 820548  132067779  5449055  Z3059345      24688608.0            5
#
#                       note_type note_status             service  \
# 0       Radiology Study Results        None                None
# 36              Conference Note    Addendum                SCAN
# 87             PS Progress Note      Signed         Social Work
# 93                 Nursing Note    Addendum          Psychiatry
# 99                Nursing Notes    Addendum                None
# ...                         ...         ...                 ...
# 820262           Progress Notes      Shared     General Surgery
# 820380             Nursing Note      Signed          Psychiatry
# 820508         PS Progress Note      Signed  Clinical Dietetics
# 820524           Progress Notes      Signed     General Surgery
# 820548        Discharge Summary      Signed     General Surgery
#
#                        author     create_datetime     filing_datetime  \
# 0                        None                 NaT                 NaT
# 36             YEUNG, FRANCES 2021-08-24 17:00:02 2021-09-03 16:52:13
# 87            EDWARDS, ASHLEY 2021-08-25 15:51:57 2021-08-25 16:07:28
# 93      BARTLEY, CHRYSTELANNE 2021-08-25 15:51:49 2021-08-25 22:52:20
# 99             BABAYAN, KATHY 2021-08-25 16:10:29 2021-08-25 17:16:24
# ...                       ...                 ...                 ...
# 820262        DENG, XIAO XUAN 2021-08-25 06:52:16 2021-08-25 06:55:20
# 820380          ALAY, DEBORAH 2021-08-25 07:00:00 2021-08-25 14:58:37
# 820508       HALIBURTON, BETH 2021-08-25 11:46:48 2021-08-25 11:50:29
# 820524      PASHYNSKYY, IRINA 2021-08-25 11:50:01 2021-08-25 11:57:37
# 820548        RAMJIST, JOSHUA 2021-08-25 11:58:13 2021-09-14 11:24:42
#
#                                                 note_text  \
# 0         PICC Insertion    Procedure performed by Dr....
# 36      Case Conference Note    Department: SK SCAN   ...
# 87      I met with Varian's mom, Yizhun, at Varian's b...
# 93      Goal of Support:     Plan/Intervention:    - C...
# 99      Assessment  VITALS: Afebrile.  NEURO: Alert an...
# ...                                                   ...
# 820262  General Surgery Progress Note    Date Of Servi...
# 820380  Assessment   Received pt at 0700 asleep with n...
# 820508  Update note- please see previous RD notes for ...
# 820524  General Surgery Progress Note    Date Of Servi...
# 820548        The Hospital for Sick Children Inpatient...
#
#                   etl_datetime
# 0      2023-05-19 12:54:55.007
# 36     2023-05-19 12:54:55.007
# 87     2023-05-19 12:54:55.007
# 93     2023-05-19 12:54:55.007
# 99     2023-05-19 12:54:55.007
# ...                        ...
# 820262 2023-05-19 12:54:55.007
# 820380 2023-05-19 12:54:55.007
# 820508 2023-05-19 12:54:55.007
# 820524 2023-05-19 12:54:55.007
# 820548 2023-05-19 12:54:55.007
#
# [178 rows x 13 columns]

# %%
df_flowsheets.dtypes
# Out:
# mrn                              int64
# REDIR_PAT_ENC_CSN_ID             int64
# AdmissionDate           datetime64[ns]
# DischargeDate           datetime64[ns]
# RECORDED_TIME           datetime64[ns]
# FLO_MEAS_ID                      int64
# FLO_MEAS_NAME                   object
# DISP_NAME                       object
# MEAS_VALUE                      object
# MEAS_COMMENT                    object
# dtype: object

# %%
df_notes.dtypes
# Out:
# note_id                    object
# mrn                        object
# pat_id                     object
# pat_enc_csn_id            float64
# note_type_id               object
# note_type                  object
# note_status                object
# service                    object
# author                     object
# create_datetime    datetime64[ns]
# filing_datetime    datetime64[ns]
# note_text                  object
# etl_datetime       datetime64[ns]
# dtype: object

# %%
df_medications.dtypes
# Out:
# order_id                         int64
# admin_line_num                   int64
# mrn                              int64
# pat_id                          object
# pat_enc_csn_id                   int64
# medication_id                    int64
# order_display_name              object
# order_datetime          datetime64[ns]
# order_start_datetime    datetime64[ns]
# order_end_datetime      datetime64[ns]
# admin_datetime          datetime64[ns]
# admin_action                    object
# drug_code                       object
# medication_name                 object
# simple_generic_name             object
# dosage_order_amount             object
# dosage_order_unit               object
# dosage_given_amount            float64
# dosage_given_unit               object
# dosing_bsa                     float64
# dosing_height                  float64
# dosing_weight                  float64
# dosing_frequency                object
# medication_route                object
# etl_datetime            datetime64[ns]
# dtype: object

# %%
df_diagnosis.dtypes
# Out:
# diagnosis_id                 int64
# mrn                          int64
# pat_id                      object
# pat_enc_csn_id             float64
# dx_id                        int64
# diagnosis_name              object
# diagnosis_code              object
# code_set                    object
# diagnosis_source            object
# date                datetime64[ns]
# date_resolution             object
# date_description            object
# resolved_date       datetime64[ns]
# is_chronic                 float64
# etl_datetime        datetime64[ns]
# dtype: object

# %%
# NOTE: pandas will silently ignore missing columns if the rename target doesn't
# exist, so we guard by only renaming when the column is present.
if 'REDIR_PAT_ENC_CSN_ID' in df_flowsheets.columns:
    df_flowsheets = df_flowsheets.rename(columns={'REDIR_PAT_ENC_CSN_ID': 'csn'})
if 'pat_enc_csn_id' in df_medications.columns:
    df_medications = df_medications.rename(columns={'pat_enc_csn_id': 'csn'})
if 'pat_enc_csn_id' in df_diagnosis.columns:
    df_diagnosis = df_diagnosis.rename(columns={'pat_enc_csn_id': 'csn'})
if 'pat_enc_csn_id' in df_notes.columns:
    df_notes = df_notes.rename(columns={'pat_enc_csn_id': 'csn'})

# Ensure MRN and CSN columns are 64-bit integers across all DataFrames
for _df in [df_patient, df_flowsheets, df_medications, df_diagnosis, df_notes]:
    if 'mrn' in _df.columns:
        _df['mrn'] = pd.to_numeric(_df['mrn'], errors='coerce').astype('Int64')
    if 'csn' in _df.columns:
        _df['csn'] = pd.to_numeric(_df['csn'], errors='coerce').astype('Int64')

# %%
df_notes[(df_notes['mrn']==2075253) & (df_notes['csn'] != 18303177)]
# Out:
#          note_id      mrn    pat_id       csn note_type_id  \
# 387702  53919782  2075253  Z1495029  18784678            1
# 401747  54034671  2075253  Z1495029  18978106           24
# 401799  54037906  2075253  Z1495029  18978106           28
# 401800  54037986  2075253  Z1495029  18978106           28
# 401801  54038015  2075253  Z1495029  18978106           28
# 401802  54038053  2075253  Z1495029  18978106           28
# 401803  54038085  2075253  Z1495029  18978106           28
# 403617  54048540  2075253  Z1495029  18978106           25
# 408882  55081944  2075253  Z1495029  19188282      1000011
# 433981  54398584  2075253  Z1495029  19041037           29
# 433982  54398603  2075253  Z1495029  19045021           29
#
#                                   note_type note_status         service  \
# 387702                       Progress Notes      Signed      Cardiology
# 401747   Anesthesia Preprocedure Evaluation    Addendum            None
# 401799           Anesthesia Procedure Notes      Signed            None
# 401800           Anesthesia Procedure Notes    Addendum            None
# 401801           Anesthesia Procedure Notes      Signed            None
# 401802           Anesthesia Procedure Notes      Signed            None
# 401803           Anesthesia Procedure Notes      Signed            None
# 403617  Anesthesia Postprocedure Evaluation      Signed            None
# 408882                        Nursing Notes      Signed  Otolaryngology
# 433981                        Addendum Note      Signed            None
# 433982                        Addendum Note      Signed            None
#
#                                author     create_datetime     filing_datetime  \
# 387702  CONTRERAS REYES, JUAN ROBERTO 2019-10-31 12:00:00 2019-11-05 07:22:04
# 401747                      YU, JULIE 2019-11-04 07:45:20 2019-11-04 09:41:35
# 401799              MACPHERSON, BRUCE 2019-11-04 09:02:43 2019-11-04 09:09:04
# 401800                      YU, JULIE 2019-11-04 09:09:08 2019-11-04 09:56:09
# 401801              MACPHERSON, BRUCE 2019-11-04 09:10:25 2019-11-04 09:11:05
# 401802              MACPHERSON, BRUCE 2019-11-04 09:11:08 2019-11-04 09:11:35
# 401803              MACPHERSON, BRUCE 2019-11-04 09:11:42 2019-11-04 09:12:18
# 403617                      YU, JULIE 2019-11-04 11:38:48 2019-11-04 16:42:39
# 408882                      NA, FAITH 2019-11-27 14:15:00 2019-11-27 14:41:42
# 433981                KIRSCH, ROXANNE 2019-11-11 19:46:02 2019-11-11 19:46:02
# 433982                KIRSCH, ROXANNE 2019-11-11 19:48:09 2019-11-11 19:48:09
#
#                                                 note_text  \
# 387702  Pre-op Clinic Note  HPI  David McDonald is 17y...
# 401747  Relevant Problems   DEVELOPMENT   (+) Global d...
# 401799    Arterial Line:    Date/Time: 4/11/2019 8:30 ...
# 401800  Airway  Date/Time: 4/11/2019 8:18 AM  Urgency:...
# 401801    Peripheral IV    Date/Time: 4/11/2019 8:13 A...
# 401802    Peripheral IV    Date/Time: 4/11/2019 8:45 A...
# 401803    Central Line:    Date/Time: 4/11/2019 8:55 A...
# 403617  Patient: David McDonald    Procedure Summary  ...
# 408882  Ears syringed at the request of Lora Carinci a...
# 433981  Addendum  created 11/11/19 1946 by Kirsch, Rox...
# 433982  Addendum  created 11/11/19 1948 by Kirsch, Rox...
#
#                   etl_datetime
# 387702 2023-05-19 12:54:55.007
# 401747 2023-05-19 12:54:55.007
# 401799 2023-05-19 12:54:55.007
# 401800 2023-05-19 12:54:55.007
# 401801 2023-05-19 12:54:55.007
# 401802 2023-05-19 12:54:55.007
# 401803 2023-05-19 12:54:55.007
# 403617 2023-05-19 12:54:55.007
# 408882 2023-05-19 12:54:55.007
# 433981 2023-05-19 12:54:55.007
# 433982 2023-05-19 12:54:55.007

# %%
df_notes[df_notes['note_id']=='55081944'].note_text.values[0]
# Out:
# 'Ears syringed at the request of Lora Carinci audiologist.  Accompanied by mother sitting in wheelchair.  Unable to remove any cerumen bilaterally despite soaking canals with water for 5 minutes. Large solid chunk of cerumen visible bilaterally. Tolerated well. Advised mom to call me when they are returning to HSC for cardiology follow up. We can try the flushing again. She will use mineral oil 4 drops to both ears qhs for 7 days before appointment. She will also put clean water to ears when showering to help dissolve cerumen    '

# %%
df_flowsheets[df_flowsheets['csn']==18303177]
# Out:
# Empty DataFrame
# Columns: [mrn, csn, AdmissionDate, DischargeDate, RECORDED_TIME, FLO_MEAS_ID, FLO_MEAS_NAME, DISP_NAME, MEAS_VALUE, MEAS_COMMENT]
# Index: []
